# %% [markdown]
# <a href="https://colab.research.google.com/github/ManeeshDhu/Discrete_Math/blob/main/DhunganaManish_CPSMA_3913_Project_5_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Module 5 : Structures**
#
# CPSMA 3913. Discrete Mathematics
#
# Student: Manish Dhungana #238129
#
# Instructor : Dr. Jacob

# %% [markdown]
# For this project, I will be graphically snowing the relationships of all the cast members of the big bang theory. It is the best sitcom of the recent decade. Sheldon Cooper is my favorite character from the show, and he is one of the main characters of the show. He is a theoretical physicist at Caltech, who is married to Neurobiologist Amy Farrah fowler.
#
# The story of The Big Bang Theory takes place in pasadena. It centers around the misadventures of physicists sheldon and his friends. Shelodon is a theoretical genius who has trouble grounding himself in the real world. He often wears different colored shirts bearing the lantern's logo, but each shirt also has a different emotion attached to it in the comic world. Red stands for rage , blue is hope, indigo is passion etc.
# ![6359819_so-min.jpeg](data:image/jpeg;base64,...)

# %%
import graphviz

cas = graphviz.Digraph('Cast')

#Main cast members
cas.node('A','Sheldon')
cas.node('B','Leonard')
cas.node('C','Raj')
cas.node('D','Penny')
cas.node('E','Howard')
cas.node('F','Amy')
cas.node('G','Bernadette')
cas.node('H','Stuart')

#family members of sheldon
cas.node('I','Missy')
cas.node('J','George')
cas.node('K','Marry Cooper')

#family members of leonard
cas.node('L','Beverly')
cas.node('M','Judd')

#family members of RAJ
cas.node('N','Dr. V.M')
cas.node('O','Mrs. Koothrappali')
cas.node('P','Priya')

#family memebrs of Howard
cas.node('Q','Mrs. Wolowitz')

#family members of Amy
cas.node('R','Mrs.Fowler')
cas.node('S','Larry Fowler')








cas.edges(['AB','AC','AD','AE','AF','AG','AH','BC','BD','BE','BF','BG','BH','CD','CE','CE','CF','CG','CH','DE','DF','DG','DH','EF','EG','EH','FG','GH','AK','KI','KJ','BL','LM','LA','CN','NO','NP','PB','DB','EQ','FR','RS'])
cas

# %% [markdown]
# By looking at the output, you can see the entire graph is connected. Everyone knows each other because of someone.
#
# There are 20 vertices and 42 edges in total. The degree of the seven main characters(vertex) comes as follows. Sheldon: 9, Raj:9, Penny:8, Howard:9, Amy:7, Leonard:9,Bernadette:6
#
# A cycle is a path which starts and ends at the same node. There are way too many cycles in my graph. One of the cycles from the graph is raj to Leonard to his mother Beverly to Sheldon. Do you know? Sheldon and Beverly are in closer contact than Leonard is with his mother.
