# %% [markdown]
# <a href="https://colab.research.google.com/github/ManeeshDhu/Discrete_Math/blob/main/DhunganaManish_CPSMA_3913_Project_Two_Functions%26Relations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Module 2 : Functions and Relations**
#
# CPSMA 3913 Discrete Mathematics
#
# Student :Manish Dhungana ID#238129
#
# Instructor : Dr. Jacob

# %% [markdown]
# # **Function**
#
# For this project, I have created a function with at least three features.
#
#  $$
# f(x) = 1+\frac{x^2-2}{{πex}}
# $$

# %%
import math
import numpy as np
#creating a function namee rato and it can only take one parameter
def rato(x):
  return (1 + ((x**2-2)/(math.pi*np.e*x)))

# %%
#calling a function   and passing  an argument 
rato(2)
# Out:
# 1.1170996630486383

# %% [markdown]
# Now to graph. I choose the window [-3,2] because that is where we can see the proper  structure.

# %%
import matplotlib.pyplot as plt
x = np.arange(-3,2,0.1)
plt.plot(x, rato(x))

# %%
#this is same graph as above but it is 3d graph
from mpl_toolkits import mplot3d

ax = plt.axes(projection='3d')
ax = np.arange(-3,2,0.1)

plt.plot(x, rato(x))

# %% [markdown]
# The function is  bjective if and only if any horizontal line will intersect the graph exactly one but the function intresect the graph multiple times thats why, my function is not bijective on the graphed domain.

# %% [markdown]
# # **Dictionaries**
# I am going to define a dictionary that creates a relationship between set heroes_One and heroes_Two

# %%
heroes_One = ["Wanda","Aquaman","Batman","Vision"]
heroes_Two = ["Arrow","Wanda","Vison","Robin"]
dictionary = dict({a:b for a,b in zip(heroes_One,heroes_Two)})

# %%
dictionary
# Out:
# {'Aquaman': 'Wanda', 'Batman': 'Vison', 'Vision': 'Robin', 'Wanda': 'Arrow'}

# %%
actualDictionary = dict({"Batman":"Robin","Vision":"Wanda","Wanda":"Vision"})

# %%
newlist2 = [actualDictionary.get(x,x) for x in heroes_One]

# %%
newlist2
# Out:
# ['Vision', 'Aquaman', 'Robin', 'Wanda']

# %% [markdown]
# The relation is not an endo relation but it is not symmetric aquaman goes to aqua girl but not back. It is not reflexive too because to be reflexive every emement of the set is related to itself.
#
# To find total possible relations between 2 sets, we can use formula n(R)=2^AB
#
#  for instance:
#
#   lets suppose set n(A) ={1,2} and set n(B) ={3}, we have to find out total possible relations(n(R))
#
#   set m has 2 elements and set n has just 1
#
#   so, n(R) = 2^AB
#
#        = 2^(2*1)
#
#        = 2^2
#
#        =4
#
#
# 65536 relations were possible because i have four elements in  each of my sets.
